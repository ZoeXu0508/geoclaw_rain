# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from gcvalid.interactive.compare_stats import Dashboard

# %%
plt.close("all")
# create two dashboards, for comparison purposes
dashboard1 = Dashboard()
dashboard2 = Dashboard()
display(dashboard1.widget)
display(dashboard2.widget)
