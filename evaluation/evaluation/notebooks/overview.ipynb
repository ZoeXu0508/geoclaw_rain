# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from gcvalid.interactive.overview import Dashboard

# %%
# %%html
# <style>
#     .widget-select > select {font-family: monospace;}
# </style>

# %%
plt.close("all")
dashboard = Dashboard()
display(dashboard.widget)
